# %%
import pandas as pd
import numpy as np
pok=np.genfromtxt("/home/fractaluser/Desktop/Untitled Folder 2/pracdata/Pokemon.csv",skip_header=0,delimiter=",",dtype='|S20')
print(pok)
# Out:
# [[b'1' b'Bulbasaur' b'Grass' ..., b'45' b'1' b'False']
#  [b'2' b'Ivysaur' b'Grass' ..., b'60' b'1' b'False']
#  [b'3' b'Venusaur' b'Grass' ..., b'80' b'1' b'False']
#  ...,
#  [b'720' b'HoopaHoopa Confined' b'Psychic' ..., b'70' b'6' b'True']
#  [b'720' b'HoopaHoopa Unbound' b'Psychic' ..., b'80' b'6' b'True']
#  [b'721' b'Volcanion' b'Fire' ..., b'70' b'6' b'True']]

# %%
names=pok[:,1].astype('|S20')
power=pok[:,4].astype('float')
powlife=[power==power.max()]
print(power.max())
print(names[powlife])
# Out:
# 780.0
# [b'MewtwoMega Mewtwo X' b'MewtwoMega Mewtwo Y' b'RayquazaMega Rayquaz']

# %%
type2=pok[:,3].astype('str')
#print(type2)
gen=pok[:,11].astype('str')
type2life=[type2=="Fighting"]
genlife=[gen=="1"]
#print(type2life)
#print(genlife)
#print(names[genlife and type2life])
life=names[genlife and type2life]
print(*life)
# Out:
# b'Poliwrath' b'MewtwoMega Mewtwo X' b'Heracross' b'HeracrossMega Heracr' b'Combusken' b'Blaziken' b'BlazikenMega Blazike' b'Breloom' b'Monferno' b'Infernape' b'LopunnyMega Lopunny' b'Croagunk' b'Toxicroak' b'Gallade' b'GalladeMega Gallade' b'Pignite' b'Emboar' b'Scraggy' b'Scrafty' b'Cobalion' b'Terrakion' b'Virizion' b'KeldeoOrdinary Forme' b'KeldeoResolute Forme' b'MeloettaPirouette Fo' b'Chesnaught'

# %%
poke_df=pd.read_csv("/home/fractaluser/Desktop/Untitled Folder 2/pracdata/Pokemon.csv")
poke_df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
poke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
poke_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
poke_df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
poke_df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
poke_df['Type 1'].value_counts()['Dark']
# Out:
# 31

# %%
type(poke_df)
# Out:
# pandas.core.frame.DataFrame

# %%
name_total=poke_df[['Name','Type 2']]
name_total
# Out:
#                           Name  Type 2
# 0                    Bulbasaur  Poison
# 1                      Ivysaur  Poison
# 2                     Venusaur  Poison
# 3        VenusaurMega Venusaur  Poison
# 4                   Charmander     NaN
# 5                   Charmeleon     NaN
# 6                    Charizard  Flying
# 7    CharizardMega Charizard X  Dragon
# 8    CharizardMega Charizard Y  Flying
# 9                     Squirtle     NaN
# 10                   Wartortle     NaN
# 11                   Blastoise     NaN
# 12     BlastoiseMega Blastoise     NaN
# 13                    Caterpie     NaN
# 14                     Metapod     NaN
# 15                  Butterfree  Flying
# 16                      Weedle  Poison
# 17                      Kakuna  Poison
# 18                    Beedrill  Poison
# 19       BeedrillMega Beedrill  Poison
# 20                      Pidgey  Flying
# 21                   Pidgeotto  Flying
# 22                     Pidgeot  Flying
# ...

# %%
poke_df.head(25)
# Out:
#      #                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur   Grass  Poison    318  45      49       49
# 1    2                    Ivysaur   Grass  Poison    405  60      62       63
# 2    3                   Venusaur   Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4    4                 Charmander    Fire     NaN    309  39      52       43
# 5    5                 Charmeleon    Fire     NaN    405  58      64       58
# 6    6                  Charizard    Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X    Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y    Fire  Flying    634  78     104       78
# 9    7                   Squirtle   Water     NaN    314  44      48       65
# 10   8                  Wartortle   Water     NaN    405  59      63       80
# ...

# %%
type1_df=poke_df[['Name','Type 1','Type 2']][0:6:2]
type1_df
# Out:
#          Name Type 1  Type 2
# 0   Bulbasaur  Grass  Poison
# 2    Venusaur  Grass  Poison
# 4  Charmander   Fire     NaN

# %%
poke_df2=pd.read_csv("/home/fractaluser/Desktop/Untitled Folder 2/pracdata/Pokemon.csv",index_col='Type 1')
poke_df2
#life=
#poke_df2.loc['Bug',['Name']]
#life.value_counts()
# Out:
#             #                       Name  Type 2  Total   HP  Attack  Defense  \
# Type 1
# Grass       1                  Bulbasaur  Poison    318   45      49       49
# Grass       2                    Ivysaur  Poison    405   60      62       63
# Grass       3                   Venusaur  Poison    525   80      82       83
# Grass       3      VenusaurMega Venusaur  Poison    625   80     100      123
# Fire        4                 Charmander     NaN    309   39      52       43
# Fire        5                 Charmeleon     NaN    405   58      64       58
# Fire        6                  Charizard  Flying    534   78      84       78
# Fire        6  CharizardMega Charizard X  Dragon    634   78     130      111
# Fire        6  CharizardMega Charizard Y  Flying    634   78     104       78
# Water       7                   Squirtle     NaN    314   44      48       65
# Water       8                  Wartortle     NaN    405   59      63       80
# ...

# %%
poke_df[poke_df['Type 1']=='Bug']['Name']
# Out:
# 13                    Caterpie
# 14                     Metapod
# 15                  Butterfree
# 16                      Weedle
# 17                      Kakuna
# 18                    Beedrill
# 19       BeedrillMega Beedrill
# 51                       Paras
# 52                    Parasect
# 53                     Venonat
# 54                    Venomoth
# 132                    Scyther
# 136                     Pinsir
# 137          PinsirMega Pinsir
# 179                     Ledyba
# 180                     Ledian
# 181                   Spinarak
# 182                    Ariados
# 208                      Yanma
# 219                     Pineco
# 220                 Forretress
# 228                     Scizor
# 229          ScizorMega Scizor
# 230                    Shuckle
# 231                  Heracross
# 232    HeracrossMega Heracross
# 288                    Wurmple
# 289                    Silcoon
# 290                  Beautifly
# 291                    Cascoon
# ...

# %%
poke_df['Legendary'].describe()
# Out:
# count       800
# unique        2
# top       False
# freq        735
# Name: Legendary, dtype: object

# %%
poke_df['Total'].describe()
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
poke=pd.read_csv("/home/fractaluser/Desktop/Untitled Folder 2/pracdata/Pokemon.csv")
#pd.options.display.max_columns=85
poke.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
total=poke['Total']

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
sns.distplot(total,kde=False)

# %%
num_poke=list(poke._get_numeric_data().columns)
print(num_poke)
poke.head()
# Out:
# ['#', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.lmplot('Attack','Speed',data=poke)

# %%
plt.figure(figsize=(10,4))
sns.heatmap(poke.corr(),cbar='viridis',annot=True)

# %%
# Out:
# pandas.core.frame.DataFrame
